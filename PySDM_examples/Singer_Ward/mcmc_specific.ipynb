# %%
from importlib import reload
import mcmc_generic
reload(mcmc_generic)
from mcmc_generic import mcmc_generic

N = 1000
mcmc_generic(filename="bcary_dark.csv", model="CompressedFilmOvadnevaite", n_steps=N, plot=True)
mcmc_generic(filename="bcary_dark.csv", model="SzyszkowskiLangmuir", n_steps=N, plot=True)
mcmc_generic(filename="bcary_dark.csv", model="CompressedFilmRuehl", n_steps=N, plot=True)
# Out:
# [4.54187924 0.53220407]
# [-2.69816612 -0.63072826]
# [7.55083254e-19 2.44088531e-07 2.40581791e+01]
# [ 75.50832535 -15.22573484   3.18047503]
# [2.23849729e-19 3.51872178e-06 2.96828334e+01 1.64083535e+17]
# [ 22.38497286 -12.55741277   3.39056888   1.64083535]
