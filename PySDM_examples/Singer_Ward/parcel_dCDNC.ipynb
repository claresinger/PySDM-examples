# %%
import sys
if 'google.colab' in sys.modules:
    # !pip --quiet install atmos-cloud-sim-uj-utils
    from atmos_cloud_sim_uj_utils import pip_install_on_colab
    pip_install_on_colab('PySDM-examples')

# %%
import warnings
from numba.core.errors import NumbaExperimentalFeatureWarning

# import os
# os.environ["NUMBA_DISABLE_JIT"] = "0"
# os.environ["NUMBA_DEVELOPER_MODE"] = "1"

import numpy as np
import matplotlib
from matplotlib import pylab

from PySDM.initialisation.sampling import spectral_sampling as spec_sampling
from PySDM.initialisation.spectra import Sum
from PySDM.physics import si

from atmos_cloud_sim_uj_utils import show_plot

from PySDM_examples.Singer_Ward import Settings, ParcelSimulation
from PySDM_examples.Singer_Ward.aerosol import AerosolBetaCaryophylleneDark

# %%
consts = {
    "MAC":1,
    "HAC":1,
    "BDF":False
    }

output = {}

lines = {'Constant': '-', 'CompressedFilmOvadnevaite': '--', 
    'SzyszkowskiLangmuir': '-.', 'CompressedFilmRuehl': ':'}
colors = {'Constant': 'k', 'CompressedFilmOvadnevaite': 'C0', 
    'SzyszkowskiLangmuir': 'C2', 'CompressedFilmRuehl': 'C1'}

aerosol = AerosolBetaCaryophylleneDark(Forg=0.5)
for model in ('Constant', 'CompressedFilmOvadnevaite', 'SzyszkowskiLangmuir', 'CompressedFilmRuehl'):
    print(model)
    key = f"{aerosol.__class__.__name__}-{model}"
    settings = Settings(
        dz=1*si.m,
        n_sd_per_mode=200, 
        model=model,
        aerosol=aerosol,
        spectral_sampling=spec_sampling.ConstantMultiplicity,
        **consts
    )
    simulation = ParcelSimulation(settings)
    with warnings.catch_warnings():
        warnings.simplefilter('ignore', category=NumbaExperimentalFeatureWarning)
        output[key] = simulation.run()
    output[key]['color'] = colors[model]
    output[key]['linestyle'] = lines[model]
    output[key]['Na_tot'] = Sum(
        tuple(settings.aerosol.modes[i]['spectrum']
                for i in range(len(settings.aerosol.modes)))).norm_factor
# Out:
# Constant
# CompressedFilmOvadnevaite
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 0
# 		 r_d
# 		 1.0400758848211657e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappaTOMS748 problem: not fa * fb < 0
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 25
# 		 r_d
# 		 2.6444249340028584e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 1
# 		 r_d
# 		 1.2821087793756157e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 50
# 		 r_d
# 		 3.443135244514155e-08
# 		 T
# 		  kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0kappa
# 		 0.043088476740650666
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particleTOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 26
# 		 r_d
# 		 2.6796355472996222e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
#
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 2
# 		 r_d
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle 1.4265830671700082e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 				 f_org
# 		 0.404040404040404
# 		 kappa
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		  27
# 		 r_d
# 		 2.7143930485415854e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.40404040404040403
# 		51
# 		 r_d
# 		 3.473268712886721e-08
# 		 kappa
# 		 0.04308847674065066
# TOMS748 problem: not fa * fb < 0 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 T
# 		 280.00000000000006
# 		 RH
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle0.9989999999999964
# 		 f_org
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 28
#
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle i
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 52
# 		 r_d
# 		 3.5033595047711647e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		  r_d
# 		 2.7487324156734395e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 3
# 		 r_d
# 		 1.5367844199176316e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 0.404040404040404
# 		 kappa
# 		 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 00.043088476740650666
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file:
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 29
# 		 r_d
# 		 2.7826854672030956e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		TOMS748 problem: not fa * fb < 0 /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 4
# 		 r_d
# 		 1.6285686836766078e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 53
# 		 r_d
# 		 3.533415207595087e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 5
# 		 r_d
# 		 1.70862341021196e-08
# 		  0.40404040404040403
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:kappa
# 		 0.04308847674065067
# T
# 		 280.00000000000006
# 		 i
# 		 30
# 		 r_d
# 		 2.8162812586063464e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_orgTOMS748 problem: not fa * fb < 0
# 		 0.40404040404040403
# 		 kappa
# 		 0.043088476740650666
#
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 		 0.4040404040404039
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		TOMS748 problem: not fa * fb < 0 kappa
# 		 0.04308847674065066
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particleTOMS748 problem: not fa * fb < 0 54
# 		 r_d
# 		 3.563443160627201e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 6
# 		 r_d
# 		 1.780464530595826e-08
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 		 31
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 55
# 		 r_d
# 		 3.593450475547344e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 r_d
# 		 2.849546418180114e-08
# 		 T
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle 280.00000000000006
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 56
#
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 r_d
# 		 3.623444055414515e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# 		 RH
# 		 0.9989999999999964
#
# TOMS748 problem: not fa * fb < 0 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 7
# 		 r_d
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle		 i
# 		 57
# 		 r_d
# 		 3.653430612199524e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 1.846192228600306e-08
# 		 T
# 		 280.00000000000006
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 32
# 		 r_d
# 		 2.882505433227967e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa		 RH
# 		 0.9989999999999964
#
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 8
# 		 r_d
# 		 1.9071715112675703e-08
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 33
# 		 r_d
# 		 2.9151808952330634e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		  58
# 		 r_d
# 		 3.6834166830297996e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# T
# 		 280.00000000000006
# 		 RH
# TOMS748 problem: not fa * fb < 0kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 59
# 		 r_d
# 		 3.7134086452773085e-08
#  kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle 34
# 		 r_d
# 		 2.9475937109542425e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 9
# 		 r_d
# 		 1.964344699377749e-08
# 		 T f_org
# 		 0.404040404040404
# 		 kappa
#
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
#  0.043088476740650666
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file:
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle/Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 10
# 		 r_d
# 		 2.0183924989893964e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.4040404040404039
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 35
# 		 r_d
# 		 2.9797632850426474e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file:
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 36
# 		 r_d
# 		 3.011707678726641e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 37
# 		 r_d
# 		 3.0434437482831005e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 38
# 		 r_d
# 		 3.074987266352961e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 11
# 		 r_d
# 		 2.0698243599355146e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 i
# 		 39
# 		 r_d
# 		 3.106353028629909e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 40
# 		 r_d
# 		 3.1375549480247406e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 12
# 		 r_d
# 		 2.1190325672089466e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 13
# 		 r_d
# 		 2.1663263345050327e-08
# 		 T
# 		 280.00000000000006
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle RH
# 		 0.9989999999999964
# 		 f_org
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 41
# 		 r_d
# 		 3.1686061380621335e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 42
# 		 r_d
# 		 3.1995189869846185e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 14
# 		 r_d
# 		 2.2119542142045283e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 15
# 		 r_d
# 		 2.2561193503228423e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 16
# 		 r_d
# 		 2.2989901704643232e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 17
# 		 r_d
# 		 2.3407080720579003e-08
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 43
# 		 r_d
# 		 3.230305223807447e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 18
# 		 r_d
# 		 2.3813930698961667e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 44
# 		 r_d
# 		 3.260975977377618e-08
# 		 T
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 				  i
# 		 19280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 		 r_d
# 		 2.4211480258122433e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 45
# 		 r_d
# 		 3.2915418293327326e-08
# 		 T
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 		 280.00000000000006
# 		 RH
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 20
# 		 r_d
# 		 2.4600618703587753e-08
# 		  0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0 kappa
# 		 0.04308847674065065
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
#
# failed to find wet radius for particle 46
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i		 r_d
# 		 3.32201286172426e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 		 21
# 		 r_d
# 		 2.4982120938031477e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 22
# 		 r_d
# 		 2.535666698201798e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.40404040404040403
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 47
# 		 r_d
# 		 3.3523986999603875e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 23
# 		 r_d
# 		 2.5724857457631858e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 00.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 48
# 		 r_d
# 		 3.382708551631786e-08
# 		 T
# 		 280.00000000000006
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particleRH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# TOMS748 problem: not fa * fb < 0
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 24
# 		 r_d
# 		 2.608722600515908e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.4040404040404039
# 		 kappa
# 		 0.043088476740650666
#
# 	file: /Users/claresinger/Research/PySDM/PySDM/backends/impl_numba/toms748.py
# failed to find wet radius for particle
# 	file: /Users/claresinger/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py
# 	context:
# 		 i
# 		 49
# 		 r_d
# 		 3.4129512417064146e-08
# 		 T
# 		 280.00000000000006
# 		 RH
# 		 0.9989999999999964
# 		 f_org
# 		 0.404040404040404
# 		 kappa
# 		 0.043088476740650666
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/j_/wj_gdgdx2jdbw7vwy0bnq5hm0000gn/T/ipykernel_22229/219371749.py in <module>
#      24         **consts
#      25     )
# ---> 26     simulation = ParcelSimulation(settings)
#      27     with warnings.catch_warnings():
#      28         warnings.simplefilter('ignore', category=NumbaExperimentalFeatureWarning)
#
# ~/Research/PySDM-examples/PySDM_examples/Singer_Ward/parcel.py in __init__(self, settings, products)
#      65             environment=env,
#      66             kappa_times_dry_volume=attributes["kappa times dry volume"],
# ---> 67             f_org=attributes["dry volume organic"] / attributes["dry volume"],
#      68         )
#      69         attributes["volume"] = settings.formulae.trivia.volume(radius=r_wet)
#
# ~/Research/PySDM/PySDM/initialisation/equilibrate_wet_radii.py in equilibrate_wet_radii(r_dry, environment, kappa_times_dry_volume, f_org, cell_id, rtol, max_iters)
#     125         r_dry=r_dry, iters=iters, T=T, RH=RH, cell_id=cell_id, kappa=kappa, rtol=rtol
#     126     )
# --> 127     assert (iters != max_iters).all() and (iters != -1).all()
#     128     return r_wet
#
# AssertionError:

# %%
figsize = (10, 5)
pylab.rc('font', size=14)
fig, axs = pylab.subplots(1, 2, figsize=figsize, sharey=True)

dat = np.zeros((len(output[key]['z']), 9))
i = 1

for idx, var in enumerate(('S_max', 'n_c_cm3')):
    for key, output_k in output.items():
        Y = np.asarray(output_k['z'])
        axs[idx].plot(output_k[var], Y, label=key.split("-")[-1], 
                      color=output_k['color'],
                      linestyle=output_k['linestyle']
                     )
        dat[:,0] = Y
        dat[:,i] = output_k[var]
        i += 1
    axs[idx].set_ylim(0, 200)
    
    axs[idx].set_ylabel('Displacement [m]')
    if var == 'S_max':
        axs[idx].set_xlabel('Supersaturation [%]')
        # axs[idx].set_xlim(0, 0.5)
    elif var == 'n_c_cm3':
        axs[idx].set_xlabel('Cloud droplet concentration [cm$^{-3}$]')
        # axs[idx].set_xlim(0, 250)
    else:
        assert False
    
for ax in axs:
    ax.grid()
axs[0].legend()
pylab.show()

# print(dat)
# np.savetxt("Ryan_parcel.csv", dat, delimiter=',', fmt='%.4f', 
#            header='z (m), SS (bulk), SS (film), CDNC (bulk) (cm-3), CDNC (film) (cm-3)')

# %%
dat = np.zeros((len(settings.wet_radius_bins_edges[:-1]), 5))
dat[:,0] = settings.wet_radius_bins_edges[:-1]
i = 1

record_number = -1
figsize = (15, 5)
pylab.rc('font', size=14)
fig, axs = pylab.subplots(1, 1, figsize=figsize, sharey=True)
for key, output_k in output.items():
    pylab.step(
        settings.wet_radius_bins_edges[:-1] / si.um,
        output_k['spectrum'],
        label=f'wet ({key})',
        color=output_k['color'],
        linestyle=output_k['linestyle'],
        where='pre'
    )
    dat[:,i] = output_k['spectrum']
    i +=1
pylab.xscale('log')
pylab.grid()
pylab.xlabel("Hydrometeor radius [μm]")
pylab.ylabel("Hydrometeor number concentration\n size distribution [mg$^{-1}$ μm$^{-1}$]")
xticks = (5,6,7,8,9,10)
#xticks = (8,9,10,11,12)
axs.set_xticks(xticks)
axs.set_xlim(xticks[0], xticks[-1])
axs.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
pylab.show()

# print(dat)
# np.savetxt("Ryan_parcel_sizedist.csv", dat, delimiter=',', fmt='%.4e', header='r_wet (m), Nc (bulk), Nc (film)')

# %%
figsize = (10, 8)
pylab.rc('font', size=14)

fig = pylab.figure(constrained_layout=False, figsize=figsize)
gs1 = fig.add_gridspec(nrows=2, ncols=2, height_ratios=[3,2], wspace=0.3, hspace=0.4)
ax1 = fig.add_subplot(gs1[0,0])
ax2 = fig.add_subplot(gs1[0,1])
ax3 = fig.add_subplot(gs1[1,:])
axs = [ax1, ax2]

for idx, var in enumerate(('S_max', 'n_c_cm3')):
    for key, output_k in output.items():
        Y = np.asarray(output_k['z'])
        axs[idx].plot(output_k[var], Y, label=key.split("-")[-1], 
                      color=output_k['color'],
                      linestyle=output_k['linestyle']
                     )
    axs[idx].set_ylim(0, 200)
    
    axs[idx].set_ylabel('Displacement [m]')
    if var == 'S_max':
        axs[idx].set_xlabel('Supersaturation [%]')
    elif var == 'n_c_cm3':
        axs[idx].set_xlabel('Cloud droplet concentration [cm$^{-3}$]')
    else:
        assert False
    
for ax in axs:
    ax.grid()

#######################

record_number = -1
for key, output_k in output.items():
    ax3.step(
        settings.wet_radius_bins_edges[:-1] / si.um,
        output_k['spectrum'],
        label=f'wet ({key})',
        color=output_k['color'],
        linestyle=output_k['linestyle'],
        where='pre'
    )
ax3.grid()
ax3.set_xlabel("Hydrometeor radius [μm]")
ax3.set_ylabel("Hydrometeor number concentration\n size distribution [mg$^{-1}$ μm$^{-1}$]")
ax3.set_xlim(5,10)

show_plot("CliMA_review_fig2.pdf")
